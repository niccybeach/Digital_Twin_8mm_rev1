# %%
import pandas as pd
import numpy as np
#Data for CoR predictions:
datas = "C:/Users/nickp/OneDrive/Documents/Fourth year/MRN/Auto training/output1.csv"

v_max = []
v_av = []
m_dot_av = []
m_dot_max = []
CoR = []
CoF = []
CoRF = []
Kn = []
spr_tan_norm = []
damp_tan_norm = []

datasr = pd.read_csv(datas)

third_col = datasr.iloc[:,2]

# Iterate through the third column and append every 3rd value to the new list
for index, value in enumerate(third_col):
    if (index + 1) % 10 == 7:  # Check if it's the 3rd value (using 0-based index)
        v_av.append((value))  # Convert the float to a string

# Iterate through the third column and append every 3rd value to the new list
for index, value in enumerate(third_col):
    if (index +1) % 10 == 1:  # Check if it's the 3rd value (using 0-based index)
        CoR.append((value))  # Convert the float to a string
        
# Iterate through the third column and append every 3rd value to the new list
for index, value in enumerate(third_col):
    if (index + 1) % 10 == 5:  # Check if it's the 3rd value (using 0-based index)
        CoF.append((value))  # Convert the float to a string
        
# Iterate through the third column and append every 3rd value to the new list
for index, value in enumerate(third_col):
    if (index + 1) % 10 == 6:  # Check if it's the 3rd value (using 0-based index)
        CoRF.append((value))  # Convert the float to a string

# Iterate through the third column and append every 3rd value to the new list
for index, value in enumerate(third_col):
    if (index + 1) % 10 == 3:  # Check if it's the 3rd value (using 0-based index)
        Kn.append((value))  # Convert the float to a string
        
# Iterate through the third column and append every 3rd value to the new list
for index, value in enumerate(third_col):
    if (index + 1) % 10 == 4:  # Check if it's the 3rd value (using 0-based index)
        spr_tan_norm.append((value))  # Convert the float to a string
        
# Iterate through the third column and append every 3rd value to the new list
for index, value in enumerate(third_col):
    if (index + 1) % 10 == 2:  # Check if it's the 3rd value (using 0-based index)
        damp_tan_norm.append((value))  # Convert the float to a string

        # Iterate through the third column and append every 3rd value to the new list
for index, value in enumerate(third_col):
    if (index + 1) % 10 == 8:  # Check if it's the 3rd value (using 0-based index)
        v_max.append((value))  # Convert the float to a string

# Iterate through the third column and append every 3rd value to the new list
for index, value in enumerate(third_col):
    if (index + 1) % 10 == 9:  # Check if it's the 3rd value (using 0-based index)
        m_dot_av.append((value))  # Convert the float to a string
        
# Iterate through the third column and append every 3rd value to the new list
for index, value in enumerate(third_col):
    if (index) % 10 == 9:  # Check if it's the 3rd value (using 0-based index)
        m_dot_max.append((value))  # Convert the float to a string
# for i in ['v_av:',v_av,
#      'CoR:',CoR,
# 'CoF:',CoF,
# 'CoRF:',CoRF,
# 'Kn:',Kn,
# 'spr_tan_norm:',spr_tan_norm,
# 'damp_tan_norm:',damp_tan_norm,
#          'm_dot_max:', m_dot_max,
#          'm_dot_av:', m_dot_av,
#          'v_max:',v_max]:
#     print(i)

print('-----------')
print('no of runs:',len(v_av))   
print('no of runs left:', 729-len(v_av))
# print(v_max)
# Out:
# -----------
# no of runs: 729
# no of runs left: 0

# %%
import numpy as np
import matplotlib.pyplot as plt
X = np.array(range(0,len(v_av)))
# Generating sample arrays
array1 = np.array([CoR])  # Assuming CoR is defined
array3 = np.array([CoF])
array4 = np.array([spr_tan_norm])
array5 = np.array([CoRF])
array6 = np.array([damp_tan_norm])
array7= np.array([Kn])

array2 = np.array([v_av])  # Assuming v_av is defined

# Finding indices and values of specific numbers in array1
values_01 = np.where(array1 == 0.1)
values_05 = np.where(array1 == 0.5)
values_09 = np.where(array1 == 0.9)


values_011 = np.where(array3 == 0.1)
values_055 = np.where(array3 == 0.5)
values_099 = np.where(array3 == 0.9)

values_0111 = np.where(array4 == 0.1)
values_0555 = np.where(array4 == 0.5)
values_0999 = np.where(array4 == 0.9)

values_01111 = np.where(array5 == 0.001)
values_05555 = np.where(array5 == 0.005)
values_09999 = np.where(array5 == 0.009)

values_011111 = np.where(array6 == 0.1)
values_055555 = np.where(array6 == 0.5)
values_099999 = np.where(array6 == 0.9)

values_0111111 = np.where(array7 == 100)
values_0555555 = np.where(array7 == 1000)
values_0999999 = np.where(array7 == 10000)

# %%
plt.figure()
plt.xlabel('Test number')
plt.ylabel('m_dot_av [kg/s]')
plt.plot(X[0:243], array2[values_01],'o', label='CoR= 0,1')
plt.plot(X[243:486], array2[values_05], 'o', label='CoR= 0,5')
plt.plot(X[486:729], array2[values_09], 'o', label='CoR= 0,9')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure()
plt.xlabel('Test number')
plt.ylabel('m_dot_av [kg/s]')
plt.plot(X[values_011[1]], array2[values_011], 'o', label='CoF = 0.1')
plt.plot(X[values_055[1]], array2[values_055], 'o', label='CoF = 0.5')
plt.plot(X[values_099[1]], array2[values_099], 'o', label='CoF = 0.9')
plt.legend()
plt.grid()
plt.show()

plt.figure()
plt.xlabel('Test number')
plt.ylabel('v_avg [m/s]')
plt.plot(X[0:243], array2[values_011],'o', label='CoF = 0,1')
plt.plot(X[243:486], array2[values_055], 'o', label='CoF = 0,5')
plt.plot(X[486:729], array2[values_099], 'o', label='CoF = 0,9')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure()
plt.xlabel('Test number')
plt.ylabel('m_dot_av [kg/s]')
plt.plot(X[values_0111[1]], array2[values_0111], 'o', label='spr tan norm = 0.1')
plt.plot(X[values_0555[1]], array2[values_0555], 'o', label='spr tan norm = 0.5')
plt.plot(X[values_0999[1]], array2[values_0999], 'o', label='spr tan norm = 0.9')
plt.legend()
plt.grid()
plt.show()

plt.figure()
plt.xlabel('Test number')
plt.ylabel('v_avg [m/s]')
plt.plot(X[0:243], array2[values_0111],'o', label='spr tan norm= 0,1')
plt.plot(X[243:486], array2[values_0555], 'o', label='spr tan norm= 0,5')
plt.plot(X[486:729], array2[values_0999], 'o', label='spr tan norm= 0,9')
plt.legend()
plt.grid()

# %%
plt.show()
plt.figure()
plt.xlabel('Test number')
plt.ylabel('v_avg [m/s]')
plt.plot(X[values_01111[1]], array2[values_01111], 'o', label='CoRF = 0.001')
plt.plot(X[values_05555[1]], array2[values_05555], 'o', label='CoRF = 0.005')
plt.plot(X[values_09999[1]], array2[values_09999], 'o', label='CoRF = 0.009')
plt.legend()
plt.grid()
plt.show()

plt.figure()
plt.xlabel('Test number')
plt.ylabel('v_avg [m/s]')
plt.plot(X[0:243], array2[values_01111],'o', label='CoRF: 0,1')
plt.plot(X[243:486], array2[values_05555], 'o', label='CoRF: 0,5')
plt.plot(X[486:729], array2[values_09999], 'o', label='CoRF: 0,9')
plt.legend()
plt.grid()

# %%
plt.figure()
plt.xlabel('Test number')
plt.ylabel('m_dot_av [kg/s]')
plt.plot(X[values_011111[1]], array2[values_011111], 'o', label='damp tan norm = 0.1')
plt.plot(X[values_055555[1]], array2[values_055555], 'o', label='damp tan norm  = 0.5')
plt.plot(X[values_099999[1]], array2[values_099999], 'o', label='damp tan norm  = 0.9')
plt.legend()
plt.grid()
plt.show()

plt.figure()
plt.xlabel('Test number')
plt.ylabel('v_avg [m/s]')
plt.plot(X[0:243], array2[values_011111],'o', label='damp tan norm = 0,1')
plt.plot(X[243:486], array2[values_055555], 'o', label='damp tan norm = 0,5')
plt.plot(X[486:729], array2[values_099999], 'o', label='damp tan norm = 0,9')
plt.legend()
plt.grid()

# %%
plt.figure()
plt.xlabel('Test number')
plt.ylabel('m_dot_av [kg/s]')
plt.plot(X[values_0111111[1]], array2[values_0111111], 'o', label='Kn = 100')
plt.plot(X[values_0555555[1]], array2[values_0555555], 'o', label='Kn = 1000 ')
plt.plot(X[values_0999999[1]], array2[values_0999999], 'o', label='Kn = 10000')
plt.legend()
plt.grid()
plt.show()

plt.figure()
plt.xlabel('Test number')
plt.ylabel('v_avg [m/s]')
plt.plot(X[0:243], array2[values_0111111],'o', label='Kn = 100')
plt.plot(X[243:486], array2[values_0555555], 'o', label='Kn = 1000')
plt.plot(X[486:729], array2[values_0999999], 'o', label='Kn = 10000')
plt.legend()
plt.grid()
